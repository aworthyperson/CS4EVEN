# %%
library(data.table)
library(lubridate)
library(reshape2)
library(scales)
library(zoo)
library(plyr)
library(stats)
library(quantmod)
library(readxl)
library(data.table)
library(lubridate)
library(reshape2)
library(scales)
library(zoo)
library(plyr)
library(lubridate)
library(reshape2)
library(scales)
invisible(1:13) # hides it
library(repr)
library(ggplot2)

options(repr.plot.width=5, repr.plot.height=4) #controls plot size in jupyter
# Out:
# Attaching package: ‘lubridate’
#
# The following objects are masked from ‘package:data.table’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# The following object is masked from ‘package:base’:
#
#     date
#
#
# Attaching package: ‘reshape2’
#
# The following objects are masked from ‘package:data.table’:
#
#     dcast, melt
#
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Attaching package: ‘plyr’
#
# The following object is masked from ‘package:lubridate’:
#
#     here
#
# Loading required package: xts
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
#
# Attaching package: ‘xts’
#
# The following objects are masked from ‘package:data.table’:
#
#     first, last
#
# Loading required package: TTR
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# ...

# %%
#import dataset 
df<- read.csv("result.csv")
head(df)
colnames(df)
# Out:
#   X         X.1 Date_Time                 air_temp_set_1 wind_speed_set_1 WBGT
# 1 Date_Time 1   2022-11-01 12:55:00+00:00 44             0                NA
# 2 Date_Time 2   2022-11-01 13:55:00+00:00 43             1                NA
# 3 Date_Time 3   2022-11-01 14:55:00+00:00 44             0                NA
# 4 Date_Time 4   2022-11-01 15:55:00+00:00 44             2                NA
# 5 Date_Time 5   2022-11-01 16:55:00+00:00 47             0                NA
# 6 Date_Time 6   2022-11-01 17:55:00+00:00 49             0                NA
#   unit TA unit.1 TG unit.2 RH unit.3
# 1      NA        NA        NA
# 2      NA        NA        NA
# 3      NA        NA        NA
# 4      NA        NA        NA
# 5      NA        NA        NA
# 6      NA        NA        NA
#  [1] "X"                "X.1"              "Date_Time"        "air_temp_set_1"
#  [5] "wind_speed_set_1" "WBGT"             "unit"             "TA"
# ...

# %%
options(repr.plot.width=10, repr.plot.height=6) #controls plot size in jupyter



ggplot(df, aes(x = Date_Time, y = TA)) +
     geom_point()
# Out:
# Warning message:
# “Removed 240 rows containing missing values (geom_point).”
# plot without title
